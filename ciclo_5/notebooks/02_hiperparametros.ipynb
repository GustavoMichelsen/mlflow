# %% [markdown]
# # 0. Imports

# %% [markdown]
# ## 0.1 Bibliotecas

# %%
from IPython.display import display, HTML

# %%
import sys

sys.path.insert(0, '../src/')

import joblib
from sklearn.pipeline              import Pipeline
from sklearn.preprocessing         import StandardScaler
from feature_engine.discretisation import EqualFrequencyDiscretiser
from feature_engine.imputation     import MeanMedianImputer
from feature_engine.wrappers       import SklearnTransformerWrapper
from sklearn.linear_model          import LogisticRegression

from utils.utils               import load_config_file
from data.dataload             import DataLoad
from data.datavalidation       import DataValidation
from data.datatranformation    import DataTransformation
from data.datapreprocessing    import DataPreprocess
from train.train               import TrainModel
from evaluation.classfier_eval import ModelEvaluation

# %% [markdown]
# ## 0.2 Funções de Ajuda

# %% [markdown]
# ## 0.3 Configurações do Jupyter

# %%
# Deixar o jupyper em widescreen
display(HTML("<style>.container { width:90% !important; }</style>"))

# Seta o máximo de colunas e linhas que o pandas vai exibir
# pd.set_option('display.max_columns', 20)
# pd.set_option('display.max_rows', 60)
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# # 1. DataLoad

# %%
dl = DataLoad()
df = dl.load_data('train_dataset_name')
df.head(1)
# Out:
#    target  TaxaDeUtilizacaoDeLinhasNaoGarantidas  Idade  \
# 0       1                               0.766127     45
#
#    NumeroDeVezes30-59DiasAtrasoNaoPior  TaxaDeEndividamento  RendaMensal  \
# 0                                    2             0.802982       9120.0
#
#    NumeroDeLinhasDeCreditoEEmprestimosAbertos  NumeroDeVezes90DiasAtraso  \
# 0                                          13                          0
#
#    NumeroDeEmprestimosOuLinhasImobiliarias  \
# 0                                        6
#
#    NumeroDeVezes60-89DiasAtrasoNaoPior  NumeroDeDependentes
# 0                                    0                  2.0

# %% [markdown]
# # 2.Data Validation

# %%
dv = DataValidation()
dv.run(dataframe=df)
# Out:
# 2024-01-08 07:32:06 [info     ] Validação Concluída
# True

# %% [markdown]
# # 3. DataTransformation

# %%
dt = DataTransformation(df)
X_train, X_val, y_train, y_val = dt.train_test_spliting()

# %% [markdown]
# # 4. Experimentation

# %%
import mlflow
from mlflow.tracking import MlflowClient

# %%
mlflow.set_tracking_uri('http://127.0.0.1:5000/')
mlflow.set_experiment('prob_learng')
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1704470502137, experiment_id='1', last_update_time=1704470502137, lifecycle_stage='active', name='prob_learng', tags={}>

# %%
# with mlflow.start_run(run_name='baseline'):
#     mlflow.set_tag('model_name', 'lr_baseline')

#     # 1. Processar os dados
#     pipe = Pipeline([('imputer',  MeanMedianImputer(variables=load_config_file().get('vars_imputer'))),
#                      ('scaler', SklearnTransformerWrapper(StandardScaler())) ])
#     preprocessador = DataPreprocess(pipe=pipe)
#     preprocessador.train(X_train)

#     X_train = preprocessador.tranform(X_train)
#     X_val = preprocessador.tranform(X_val)
#     joblib.dump(preprocessador, '../models/preprocessador.joblib')

#     # 1.1 Logar um artefato

#     mlflow.log_artifacts('../models/preprocessador.joblib')

#     # 1.2 logar os parametros do processador

#     mlflow.log_params(params={'imputer': pipe['imputer'],
#                               'scaler' : pipe['scaler']})
    
#     # 2.0 inicia o experimento com cross validation

#     model = LogisticRegression()
#     model_eval = ModelEvaluation(model, X_train, y_train)
#     roc_auc_curve = model_eval.cross_val_eval()

#     # 2.1 Logar o Resultado da Performance

#     mlflow.log_metric('train_roc_auc', roc_auc_curve.mean())
    
#     # 3.0 Treinamento do Modelo

#     model.fit(X_train, y_train)

#     # 4.0 salvar as métricas de validação do modelo

#     y_pred = model_eval.model.predict_proba(X_val)[:, 1]
#     val_roc_curve = model_eval.evaluate_prediction(y_val, y_pred)
#     mlflow.log_metric('valid_roc_curve', val_roc_curve)

#      # 5.0 Logar o modelo criado
#     mlflow.sklearn.log_model(model,
#                              'lr_model',
#                              pyfunc_predict_fn='predict_proba')

#     mlflow.end_run()

# %% [markdown]
# ## 4.1 Hyperparameters

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK
from mlflow.models import MetricThreshold
from sklearn.dummy import DummyClassifier
from mlflow.models import infer_signature

# %%
pipe = Pipeline([('imputer',  MeanMedianImputer(variables=load_config_file().get('vars_imputer'))),
                 ('discretizer', EqualFrequencyDiscretiser(variables=load_config_file().get('vars_discritiser'))),
                 ('scaler', SklearnTransformerWrapper(StandardScaler())) ])

# %%
def objective(params, X_train, X_val):
    with mlflow.start_run(run_name='with_discretizer_hyperopt'):
        mlflow.set_tag('model_name', 'lr_hyperopt')
        mlflow.log_params(params)
        
    
        preprocessador = DataPreprocess(pipe)
        preprocessador.train(X_train)
        
        X_train = preprocessador.transform(X_train)
        X_val = preprocessador.transform(X_val)
        joblib.dump(preprocessador, '../models/preprocess.joblib')
        
        ## 1.1. logar um artefato (preprocessador)
        mlflow.log_artifact('../models/preprocess.joblib')
        
        ## 1.2. logar os parametros do preprocessador
        mlflow.log_params(params={'imputer': pipe['imputer'],
                                'discretizer': pipe['discretizer'],
                                'scaler': pipe['scaler']})
        
        # 2.0. inicia o experimento com cross validatin
        model = LogisticRegression(**params)
        model_eval = ModelEvaluation(model,
                                    X_train,
                                    y_train,
                                    n_splits=5)
        roc_auc_scores = model_eval.cross_val_eval()
        ## 2.1. logar o resultado da performance
        mlflow.log_metric('train_roc_auc', roc_auc_scores.mean())
        
        # 3.0. treinar o modelo
        model.fit(X_train, y_train)
        
        # 4.0. salvar as metricas de validacao do modelo
        y_val_preds = model_eval.model.predict_proba(X_val)[:, 1]
        val_roc_auc = model_eval.evaluate_prediction(y_val, y_val_preds)
        
        mlflow.log_metric('valid_roc_auc', val_roc_auc)
        
        # 5.0. logar o modelo
        candidate_model_uri = mlflow.sklearn.log_model(model,
                                'lr_model').model_uri
        
        ########
        signature = infer_signature(X_val, y_val)
        
        eval_data = X_val
        eval_data['label'] = y_val
        
        thresholds = {
            "accuracy_score": MetricThreshold(
                threshold=0.1, # o score da acuracia precisa ser >0.7
                min_absolute_change=0.05,
                min_relative_change=0.05, 
                greater_is_better=True
            )
        }
        
        baseline_model = DummyClassifier(strategy='uniform').fit(X_train, y_train)
        baseline_model_uri = mlflow.sklearn.log_model(baseline_model,
                                                    "baseline_model",
                                                    signature=signature).model_uri
        
        # processo responsavel por avaliar o modelo do mlflow
        mlflow.evaluate(candidate_model_uri,
                        eval_data,
                        targets="label",
                        model_type="classifier",
                        validation_thresholds=thresholds,
                        baseline_model=baseline_model_uri)
        
        
        mlflow.end_run()
        
        return {'loss': -roc_auc_scores.mean(),
                'status': STATUS_OK}

# %%
search_space = {
                'warm_start' : hp.choice('warm_start', [True, False]),
                'fit_intercept' : hp.choice('fit_intercept', [True, False]),
                'tol' : hp.uniform('tol', 0.00001, 0.0001),
                'C' : hp.uniform('C', 0.05, 3),
                'solver' : hp.choice('solver', ['newton-cg', 'lbfgs', 'liblinear']),
                'max_iter' : hp.choice('max_iter', range(100,400)),
                'multi_class' : 'auto',
                'class_weight' : hp.choice('class_weight', [None, 'balanced'])
               }

# %%
best_result = fmin(fn=lambda params: objective(params, X_train, X_val),
                   space=search_space,
                   algo=tpe.suggest,
                   max_evals=20)
# Out:
#   0%|                                                                           | 0/20 [00:00<?, ?trial/s, best loss=?]
# Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#
# Setuptools is replacing distutils.
#
# Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#
# Setuptools is replacing distutils.
#
# Downloading artifacts:   0%|                                                                     | 0/5 [00:00<?, ?it/s]
#
# Downloading artifacts:  20%|############2                                                | 1/5 [00:00<00:00,
/s]
#
# Downloading artifacts:  20%|############2                                                | 1/5 [00:00<00:00,  9.50it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00,  9.50it/s]
#
# Downloading artifacts:  60%|####################################6                        | 3/5 [00:00<00:00,  9.50it/s]
#
# Downloading artifacts:  80%|################################################8            | 4/5 [00:00<00:00,  9.50it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00,  9.50it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 31.00it/s]
# Downloading artifacts:   0%|                                                                     | 0/5 [00:00<?, ?it/s]
#
# Downloading artifacts:  20%|############2                                                | 1/5 [00:00<00:00, 14.36it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 19.71it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 19.71it/s]
#
# Downloading artifacts:  60%|####################################6                        | 3/5 [00:00<00:00, 19.71it/s]
#
# Downloading artifacts:  80%|################################################8            | 4/5 [00:00<00:00, 19.71it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 19.71it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 36.24it/s]
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#
# 2024/01/08 08:09:46 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
#
# 2024/01/08 08:09:46 INFO mlflow.models.evaluation.default_evaluator: Evaluating candidate model:
#
# 2024/01/08 08:09:46 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
#
# 2024/01/08 08:09:46 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
#
# 2024/01/08 08:09:46 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
#
# 2024/01/08 08:09:48 INFO mlflow.models.evaluation.default_evaluator: Shap explainer LinearExplainer is used.
#
# Unable to serialize underlying model using MLflow, will use SHAP serialization
#
# 2024/01/08 08:09:48 WARNING mlflow.models.evaluation.default_evaluator: Logging explainer failed. Reason: AttributeError("'LogisticRegression' object has no attribute 'save'"). Set logging level to DEBUG to see the full traceback.
#
# 2024/01/08 08:09:51 INFO mlflow.models.evaluation.default_evaluator: Evaluating baseline model:
#
# 2024/01/08 08:09:51 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
#
# 2024/01/08 08:09:51 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
#
# 2024/01/08 08:09:51 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
#
# 2024/01/08 08:09:51 INFO mlflow.models.evaluation.base: Validating generated model metrics
#
# 2024/01/08 08:09:51 INFO mlflow.models.evaluation.base: Model validation passed!
#  40%|███████████████████▏                            | 8/20 [03:14<04:47, 23.98s/trial, best loss: -0.8480782400769659]
# Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#
# Setuptools is replacing distutils.
#
# Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#
# Setuptools is replacing distutils.
#
# Downloading artifacts:   0%|                                                                     | 0/5 [00:00<?, ?it/s]
#
# Downloading artifacts:  20%|############2                                                | 1/5 [00:00<00:00, 10.86it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 19.81it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 19.81it/s]
#
# Downloading artifacts:  60%|####################################6                        | 3/5 [00:00<00:00, 19.81it/s]
#
# Downloading artifacts:  80%|################################################8            | 4/5 [00:00<00:00, 19.81it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 19.81it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 35.46it/s]
# Downloading artifacts:   0%|                                                                     | 0/5 [00:00<?, ?it/s]
#
# Downloading artifacts:  20%|############2                                                | 1/5 [00:00<00:00, 17.12it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 12.69it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 12.69it/s]
#
# Downloading artifacts:  60%|####################################6                        | 3/5 [00:00<00:00, 12.69it/s]
#
# Downloading artifacts:  80%|################################################8            | 4/5 [00:00<00:00, 12.69it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 12.69it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 26.91it/s]
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#
# 2024/01/08 08:10:11 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
#
# 2024/01/08 08:10:11 INFO mlflow.models.evaluation.default_evaluator: Evaluating candidate model:
#
# 2024/01/08 08:10:12 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
#
# 2024/01/08 08:10:12 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
#
# 2024/01/08 08:10:12 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
#
# 2024/01/08 08:10:14 INFO mlflow.models.evaluation.default_evaluator: Shap explainer LinearExplainer is used.
#
# Unable to serialize underlying model using MLflow, will use SHAP serialization
#
# 2024/01/08 08:10:14 WARNING mlflow.models.evaluation.default_evaluator: Logging explainer failed. Reason: AttributeError("'LogisticRegression' object has no attribute 'save'"). Set logging level to DEBUG to see the full traceback.
#
# ...
#
# Setuptools is replacing distutils.
#
# Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#
# Setuptools is replacing distutils.
#
# Downloading artifacts:   0%|                                                                     | 0/5 [00:00<?, ?it/s]
#
# Downloading artifacts:  20%|############2                                                | 1/5 [00:00<00:00, 16.53it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 24.77it/s]
#
# Downloading artifacts:  60%|####################################6                        | 3/5 [00:00<00:00, 29.86it/s]
#
# Downloading artifacts:  60%|####################################6                        | 3/5 [00:00<00:00, 29.86it/s]
#
# Downloading artifacts:  80%|################################################8            | 4/5 [00:00<00:00, 29.86it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 29.86it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 38.94it/s]
# Downloading artifacts:   0%|                                                                     | 0/5 [00:00<?, ?it/s]
#
# Downloading artifacts:  20%|############2                                                | 1/5 [00:00<00:00, 13.94it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 19.62it/s]
#
# Downloading artifacts:  60%|####################################6                        | 3/5 [00:00<00:00, 27.46it/s]
#
# Downloading artifacts:  60%|####################################6                        | 3/5 [00:00<00:00, 27.46it/s]
#
# Downloading artifacts:  80%|################################################8            | 4/5 [00:00<00:00, 27.46it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 27.46it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 38.75it/s]
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#
# 2024/01/08 08:13:45 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
#
# 2024/01/08 08:13:45 INFO mlflow.models.evaluation.default_evaluator: Evaluating candidate model:
#
# 2024/01/08 08:13:45 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
#
# 2024/01/08 08:13:45 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
#
# 2024/01/08 08:13:45 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
#
# 2024/01/08 08:13:47 INFO mlflow.models.evaluation.default_evaluator: Shap explainer LinearExplainer is used.
#
# Unable to serialize underlying model using MLflow, will use SHAP serialization
#
# 2024/01/08 08:13:47 WARNING mlflow.models.evaluation.default_evaluator: Logging explainer failed. Reason: AttributeError("'LogisticRegression' object has no attribute 'save'"). Set logging level to DEBUG to see the full traceback.
#
# 2024/01/08 08:13:50 INFO mlflow.models.evaluation.default_evaluator: Evaluating baseline model:
#
# 2024/01/08 08:13:50 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
#
# 2024/01/08 08:13:50 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
#
# 2024/01/08 08:13:50 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
#
# 2024/01/08 08:13:50 INFO mlflow.models.evaluation.base: Validating generated model metrics
#
# 2024/01/08 08:13:50 INFO mlflow.models.evaluation.base: Model validation passed!
#  90%|██████████████████████████████████████████▎    | 18/20 [07:13<00:47, 23.89s/trial, best loss: -0.8480782400769659]
# Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#
# Setuptools is replacing distutils.
#
# Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#
# Setuptools is replacing distutils.
#
# Downloading artifacts:   0%|                                                                     | 0/5 [00:00<?, ?it/s]
#
# Downloading artifacts:  20%|############2                                                | 1/5 [00:00<00:00, 13.31it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 22.82it/s]
#
# Downloading artifacts:  60%|####################################6                        | 3/5 [00:00<00:00, 28.81it/s]
#
# Downloading artifacts:  60%|####################################6                        | 3/5 [00:00<00:00, 28.81it/s]
#
# Downloading artifacts:  80%|################################################8            | 4/5 [00:00<00:00, 28.81it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 28.81it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 36.61it/s]
# Downloading artifacts:   0%|                                                                     | 0/5 [00:00<?, ?it/s]
#
# Downloading artifacts:  20%|############2                                                | 1/5 [00:00<00:00, 14.63it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 18.74it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 18.74it/s]
#
# Downloading artifacts:  60%|####################################6                        | 3/5 [00:00<00:00, 18.74it/s]
#
# Downloading artifacts:  80%|################################################8            | 4/5 [00:00<00:00, 18.74it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 18.74it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 37.74it/s]
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#
# 2024/01/08 08:14:12 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
#
# 2024/01/08 08:14:12 INFO mlflow.models.evaluation.default_evaluator: Evaluating candidate model:
#
# 2024/01/08 08:14:12 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
#
# 2024/01/08 08:14:12 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
#
# 2024/01/08 08:14:12 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
#
# 2024/01/08 08:14:14 INFO mlflow.models.evaluation.default_evaluator: Shap explainer LinearExplainer is used.
#
# Unable to serialize underlying model using MLflow, will use SHAP serialization
#
# 2024/01/08 08:14:14 WARNING mlflow.models.evaluation.default_evaluator: Logging explainer failed. Reason: AttributeError("'LogisticRegression' object has no attribute 'save'"). Set logging level to DEBUG to see the full traceback.
#
# 2024/01/08 08:14:16 INFO mlflow.models.evaluation.default_evaluator: Evaluating baseline model:
#
# 2024/01/08 08:14:16 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
#
# 2024/01/08 08:14:16 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
#
# 2024/01/08 08:14:17 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
#
# 2024/01/08 08:14:17 INFO mlflow.models.evaluation.base: Validating generated model metrics
#
# 2024/01/08 08:14:17 INFO mlflow.models.evaluation.base: Model validation passed!
#  95%|████████████████████████████████████████████▋  | 19/20 [07:40<00:24, 24.63s/trial, best loss: -0.8480782400769659]
# Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#
# Setuptools is replacing distutils.
#
# Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#
# Setuptools is replacing distutils.
#
# Downloading artifacts:   0%|                                                                     | 0/5 [00:00<?, ?it/s]
#
# Downloading artifacts:  20%|############2                                                | 1/5 [00:00<00:00, 19.41it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 18.08it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 18.08it/s]
#
# Downloading artifacts:  60%|####################################6                        | 3/5 [00:00<00:00, 18.08it/s]
#
# Downloading artifacts:  80%|################################################8            | 4/5 [00:00<00:00, 18.08it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 18.08it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 35.96it/s]
# Downloading artifacts:   0%|                                                                     | 0/5 [00:00<?, ?it/s]
#
# Downloading artifacts:  20%|############2                                                | 1/5 [00:00<00:00, 12.07it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 18.27it/s]
#
# Downloading artifacts:  40%|########################4                                    | 2/5 [00:00<00:00, 18.27it/s]
#
# Downloading artifacts:  60%|####################################6                        | 3/5 [00:00<00:00, 18.27it/s]
#
# Downloading artifacts:  80%|################################################8            | 4/5 [00:00<00:00, 18.27it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 18.27it/s]
#
# Downloading artifacts: 100%|#############################################################| 5/5 [00:00<00:00, 39.35it/s]
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#
# 2024/01/08 08:14:39 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
#
# 2024/01/08 08:14:39 INFO mlflow.models.evaluation.default_evaluator: Evaluating candidate model:
#
# 2024/01/08 08:14:39 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
#
# 2024/01/08 08:14:39 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
#
# 2024/01/08 08:14:39 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
#
# 2024/01/08 08:14:41 INFO mlflow.models.evaluation.default_evaluator: Shap explainer LinearExplainer is used.
#
# Unable to serialize underlying model using MLflow, will use SHAP serialization
#
# 2024/01/08 08:14:41 WARNING mlflow.models.evaluation.default_evaluator: Logging explainer failed. Reason: AttributeError("'LogisticRegression' object has no attribute 'save'"). Set logging level to DEBUG to see the full traceback.
#
# 2024/01/08 08:14:43 INFO mlflow.models.evaluation.default_evaluator: Evaluating baseline model:
#
# 2024/01/08 08:14:43 INFO mlflow.models.evaluation.default_evaluator: Computing model predictions.
#
# 2024/01/08 08:14:43 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
#
# 2024/01/08 08:14:43 INFO mlflow.models.evaluation.default_evaluator: Testing metrics on first row...
#
# 2024/01/08 08:14:43 INFO mlflow.models.evaluation.base: Validating generated model metrics
#
# 2024/01/08 08:14:43 INFO mlflow.models.evaluation.base: Model validation passed!
# 100%|███████████████████████████████████████████████| 20/20 [08:07<00:00, 24.35s/trial, best loss: -0.8480782400769659]
